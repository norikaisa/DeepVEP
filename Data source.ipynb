# %%
import os
import random
from PIL import Image
import numpy as np

# %%
path_to_file = "/Users/norikaisa/Downloads/VEP12_23_10.jpg"
path_to_file1 = "/Users/norikaisa/Downloads/VEP12_23_101.jpg"

# %%
# Use the image library to open my intended file
im_frame = Image.open(path_to_file)
im_frame1 = Image.open(path_to_file1)

# turn the imported image into a numpy array
np_frame = np.array(im_frame)
np_frame1 = np.array(im_frame1)

# %%
xlim = 30
ylim = 50
data = np.zeros((xlim, ylim, 3), dtype = np.int8)

# %%
a = 100

# %%
## save normal

# %%
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][760].sum() < a):
    img.save('my1.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][778].sum() < a):
    img.save('my2.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+214][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1230][790].sum() < a):
    img.save('my3.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+231][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][800].sum() < a):
    img.save('my4.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][800].sum() < a):
    img.save('my5.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1185][690].sum() < a):
    img.save('my6.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1220][730].sum() < a):
    img.save('my7.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1240][760].sum() < a):
    img.save('my8.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250][j+320])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][780].sum() < a):
    img.save('my9.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][650].sum() < a):
    img.save('my10.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][700].sum() < a):
    img.save('my11.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+270][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][740].sum() < a):
    img.save('my12.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1275][770].sum() < a):
    img.save('my13.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][790].sum() < a):
    img.save('my14.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][800].sum() < a):
    img.save('my15.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][650].sum() < a):
    img.save('my16.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1310][700].sum() < a):
    img.save('my17.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][740].sum() < a):
    img.save('my18.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][770].sum() < a):
    img.save('my19.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][790].sum() < a):
    img.save('my20.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+300][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][800].sum() < a):
    img.save('my21.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1380][690].sum() < a):
    img.save('my22.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1350][730].sum() < a):
    img.save('my23.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1325][760].sum() < a):
    img.save('my24.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335][j+320])
img = Image.fromarray(data, "RGB")
if (np_frame1[1305][780].sum() < a):
    img.save('my25.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1420][760].sum() < a):
    img.save('my26.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1374][778].sum() < a):
    img.save('my27.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+370][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1340][790].sum() < a):
    img.save('my28.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1304][797].sum() < a):
    img.save('my29.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1298][800].sum() < a):
    img.save('my30.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1418][848].sum() < a):
    img.save('my31.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1372][834].sum() < a):
    img.save('my32.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+370][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1349][824].sum() < a):
    img.save('my33.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1312][816].sum() < a):
    img.save('my34.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1298][814].sum() < a):
    img.save('my35.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380][j+500])
img = Image.fromarray(data, "RGB")
if (np_frame1[1380][920].sum() < a):
    img.save('my36.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1350][882].sum() < a):
    img.save('my37.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+460])
img = Image.fromarray(data, "RGB")
if (np_frame1[1324][855].sum() < a):
    img.save('my38.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335][j+440])
img = Image.fromarray(data, "RGB")
if (np_frame1[1306][832].sum() < a):
    img.save('my39.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][962].sum() < a):
    img.save('my40.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1308][910].sum() < a):
    img.save('my41.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][870].sum() < a):
    img.save('my42.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1292][840].sum() < a):
    img.save('my43.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][820].sum() < a):
    img.save('my44.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+300][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1286][810].sum() < a):
    img.save('my45.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][960].sum() < a):
    img.save('my46.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][910].sum() < a):
    img.save('my47.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+270][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][870].sum() < a):
    img.save('my48.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1276][840].sum() < a):
    img.save('my49.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][824].sum() < a):
    img.save('my50.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1278][810].sum() < a):
    img.save('my51.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210][j+500])
img = Image.fromarray(data, "RGB")
if (np_frame1[1186][920].sum() < a):
    img.save('my52.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1118][882].sum() < a):
    img.save('my53.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235][j+460])
img = Image.fromarray(data, "RGB")
if (np_frame1[1244][856].sum() < a):
    img.save('my54.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250][j+440])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][832].sum() < a):
    img.save('my55.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][848].sum() < a):
    img.save('my56.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][834].sum() < a):
    img.save('my57.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+214][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1228][824].sum() < a):
    img.save('my58.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+231][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1254][816].sum() < a):
    img.save('my59.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][814].sum() < a):
    img.save('my60.png')

# %%
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180+470][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][240].sum() < a):
    img.save('my61.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197+470][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][252].sum() < a):
    img.save('my62.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+219+470][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1230][264].sum() < a):
    img.save('my63.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+236+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1254][270].sum() < a):
    img.save('my64.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][274].sum() < a):
    img.save('my65.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210+470][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1186][166].sum() < a):
    img.save('my66.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220+470][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1220][204].sum() < a):
    img.save('my67.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1240][230].sum() < a):
    img.save('my68.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250+470][j+320])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][254].sum() < a):
    img.save('my69.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260+470][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][124].sum() < a):
    img.save('my70.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265+470][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][176].sum() < a):
    img.save('my71.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+270+470][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][214].sum() < a):
    img.save('my72.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1274][244].sum() < a):
    img.save('my73.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280+470][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][266].sum() < a):
    img.save('my74.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285+470][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1278][276].sum() < a):
    img.save('my75.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325+470][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][124].sum() < a):
    img.save('my76.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320+470][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1308][176].sum() < a):
    img.save('my77.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315+470][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1298][214].sum() < a):
    img.save('my78.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][244].sum() < a):
    img.save('my79.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305+470][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][266].sum() < a):
    img.save('my80.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+300+470][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1286][276].sum() < a):
    img.save('my81.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380+470][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1382][166].sum() < a):
    img.save('my82.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365+470][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1348][204].sum() < a):
    img.save('my83.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1324][234].sum() < a):
    img.save('my84.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335+470][j+320])
img = Image.fromarray(data, "RGB")
if (np_frame1[1304][254].sum() < a):
    img.save('my85.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415+470][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1418][240].sum() < a):
    img.save('my86.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393+470][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1370][250].sum() < a):
    img.save('my87.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+375+470][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1340][264].sum() < a):
    img.save('my88.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+355+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1314][270].sum() < a):
    img.save('my89.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+330+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][272].sum() < a):
    img.save('my90.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1418][320].sum() < a):
    img.save('my91.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393+470][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1370][310].sum() < a):
    img.save('my92.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+370+470][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1340][298].sum() < a):
    img.save('my93.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1314][290].sum() < a):
    img.save('my94.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+330+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1296][286].sum() < a):
    img.save('my95.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380+470][j+495])
img = Image.fromarray(data, "RGB")
if (np_frame1[1382][394].sum() < a):
    img.save('my96.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365+470][j+475])
img = Image.fromarray(data, "RGB")
if (np_frame1[1350][356].sum() < a):
    img.save('my97.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350+470][j+455])
img = Image.fromarray(data, "RGB")
if (np_frame1[1324][328].sum() < a):
    img.save('my98.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335+470][j+435])
img = Image.fromarray(data, "RGB")
if (np_frame1[1306][306].sum() < a):
    img.save('my99.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325+470][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][436].sum() < a):
    img.save('my100.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320+470][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1310][384].sum() < a):
    img.save('my101.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315+470][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][346].sum() < a):
    img.save('my102.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310+470][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][314].sum() < a):
    img.save('my103.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][296].sum() < a):
    img.save('my104.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1288][284].sum() < a):
    img.save('my105.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260+470][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][436].sum() < a):
    img.save('my106.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265+470][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][386].sum() < a):
    img.save('my107.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275+470][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][346].sum() < a):
    img.save('my108.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275+470][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1276][314].sum() < a):
    img.save('my109.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][296].sum() < a):
    img.save('my110.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285+470][j+395])
img = Image.fromarray(data, "RGB")
if (np_frame1[1278][286].sum() < a):
    img.save('my111.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210+470][j+500])
img = Image.fromarray(data, "RGB")
if (np_frame1[1186][394].sum() < a):
    img.save('my112.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220+470][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1220][356].sum() < a):
    img.save('my113.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235+470][j+460])
img = Image.fromarray(data, "RGB")
if (np_frame1[1242][328].sum() < a):
    img.save('my114.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250+470][j+440])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][306].sum() < a):
    img.save('my115.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][322].sum() < a):
    img.save('my116.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197+470][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][310].sum() < a):
    img.save('my117.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+214+470][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1230][300].sum() < a):
    img.save('my118.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+236+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1254][290].sum() < a):
    img.save('my119.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][286].sum() < a):
    img.save('my120.png')

# %%
## save abnormal

# %%
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][760].sum() > a):
    img.save('my1.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][778].sum() > a):
    img.save('my2.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+214][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1230][790].sum() > a):
    img.save('my3.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+231][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][800].sum() > a):
    img.save('my4.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][800].sum() > a):
    img.save('my5.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1185][690].sum() > a):
    img.save('my6.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1220][730].sum() > a):
    img.save('my7.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1240][760].sum() > a):
    img.save('my8.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250][j+320])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][780].sum() > a):
    img.save('my9.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][650].sum() > a):
    img.save('my10.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][700].sum() > a):
    img.save('my11.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+270][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][740].sum() > a):
    img.save('my12.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1275][770].sum() > a):
    img.save('my13.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][790].sum() > a):
    img.save('my14.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][800].sum() > a):
    img.save('my15.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][650].sum() > a):
    img.save('my16.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1310][700].sum() > a):
    img.save('my17.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][740].sum() > a):
    img.save('my18.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][770].sum() > a):
    img.save('my19.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][790].sum() > a):
    img.save('my20.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+300][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][800].sum() > a):
    img.save('my21.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1380][690].sum() > a):
    img.save('my22.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1350][730].sum() > a):
    img.save('my23.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1325][760].sum() > a):
    img.save('my24.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335][j+320])
img = Image.fromarray(data, "RGB")
if (np_frame1[1305][780].sum() > a):
    img.save('my25.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1420][760].sum() > a):
    img.save('my26.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1374][778].sum() > a):
    img.save('my27.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+370][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1340][790].sum() > a):
    img.save('my28.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1304][797].sum() > a):
    img.save('my29.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1298][800].sum() > a):
    img.save('my30.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1418][848].sum() > a):
    img.save('my31.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1372][834].sum() > a):
    img.save('my32.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+370][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1349][824].sum() > a):
    img.save('my33.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1312][816].sum() > a):
    img.save('my34.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1298][814].sum() > a):
    img.save('my35.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380][j+500])
img = Image.fromarray(data, "RGB")
if (np_frame1[1380][920].sum() > a):
    img.save('my36.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1350][882].sum() > a):
    img.save('my37.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350][j+460])
img = Image.fromarray(data, "RGB")
if (np_frame1[1324][855].sum() > a):
    img.save('my38.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335][j+440])
img = Image.fromarray(data, "RGB")
if (np_frame1[1306][832].sum() > a):
    img.save('my39.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][962].sum() > a):
    img.save('my40.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1308][910].sum() > a):
    img.save('my41.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][870].sum() > a):
    img.save('my42.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1292][840].sum() > a):
    img.save('my43.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][820].sum() > a):
    img.save('my44.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+300][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1286][810].sum() > a):
    img.save('my45.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][960].sum() > a):
    img.save('my46.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][910].sum() > a):
    img.save('my47.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+270][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][870].sum() > a):
    img.save('my48.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1276][840].sum() > a):
    img.save('my49.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][824].sum() > a):
    img.save('my50.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1278][810].sum() > a):
    img.save('my51.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210][j+500])
img = Image.fromarray(data, "RGB")
if (np_frame1[1186][920].sum() > a):
    img.save('my52.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1118][882].sum() > a):
    img.save('my53.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235][j+460])
img = Image.fromarray(data, "RGB")
if (np_frame1[1244][856].sum() > a):
    img.save('my54.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250][j+440])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][832].sum() > a):
    img.save('my55.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][848].sum() > a):
    img.save('my56.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][834].sum() > a):
    img.save('my57.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+214][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1228][824].sum() > a):
    img.save('my58.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+231][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1254][816].sum() > a):
    img.save('my59.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][814].sum() > a):
    img.save('my60.png')

# %%
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180+470][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][240].sum() > a):
    img.save('my61.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197+470][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][252].sum() > a):
    img.save('my62.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+219+470][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1230][264].sum() > a):
    img.save('my63.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+236+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1254][270].sum() > a):
    img.save('my64.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][274].sum() > a):
    img.save('my65.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210+470][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1186][166].sum() > a):
    img.save('my66.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220+470][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1220][204].sum() > a):
    img.save('my67.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1240][230].sum() > a):
    img.save('my68.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250+470][j+320])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][254].sum() > a):
    img.save('my69.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260+470][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][124].sum() > a):
    img.save('my70.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265+470][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][176].sum() > a):
    img.save('my71.png')
    
for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+270+470][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][214].sum() > a):
    img.save('my72.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1274][244].sum() > a):
    img.save('my73.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280+470][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][266].sum() > a):
    img.save('my74.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285+470][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1278][276].sum() > a):
    img.save('my75.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325+470][j+220])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][124].sum() > a):
    img.save('my76.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320+470][j+245])
img = Image.fromarray(data, "RGB")
if (np_frame1[1308][176].sum() > a):
    img.save('my77.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315+470][j+270])
img = Image.fromarray(data, "RGB")
if (np_frame1[1298][214].sum() > a):
    img.save('my78.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][244].sum() > a):
    img.save('my79.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305+470][j+325])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][266].sum() > a):
    img.save('my80.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+300+470][j+360])
img = Image.fromarray(data, "RGB")
if (np_frame1[1286][276].sum() > a):
    img.save('my81.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380+470][j+260])
img = Image.fromarray(data, "RGB")
if (np_frame1[1382][166].sum() > a):
    img.save('my82.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365+470][j+280])
img = Image.fromarray(data, "RGB")
if (np_frame1[1348][204].sum() > a):
    img.save('my83.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350+470][j+300])
img = Image.fromarray(data, "RGB")
if (np_frame1[1324][234].sum() > a):
    img.save('my84.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335+470][j+320])
img = Image.fromarray(data, "RGB")
if (np_frame1[1304][254].sum() > a):
    img.save('my85.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415+470][j+335])
img = Image.fromarray(data, "RGB")
if (np_frame1[1418][240].sum() > a):
    img.save('my86.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393+470][j+345])
img = Image.fromarray(data, "RGB")
if (np_frame1[1370][250].sum() > a):
    img.save('my87.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+375+470][j+350])
img = Image.fromarray(data, "RGB")
if (np_frame1[1340][264].sum() > a):
    img.save('my88.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+355+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1314][270].sum() > a):
    img.save('my89.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+330+470][j+355])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][272].sum() > a):
    img.save('my90.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+415+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1418][320].sum() > a):
    img.save('my91.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+393+470][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1370][310].sum() > a):
    img.save('my92.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+370+470][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1340][298].sum() > a):
    img.save('my93.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1314][290].sum() > a):
    img.save('my94.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+330+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1296][286].sum() > a):
    img.save('my95.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+380+470][j+495])
img = Image.fromarray(data, "RGB")
if (np_frame1[1382][394].sum() > a):
    img.save('my96.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+365+470][j+475])
img = Image.fromarray(data, "RGB")
if (np_frame1[1350][356].sum() > a):
    img.save('my97.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+350+470][j+455])
img = Image.fromarray(data, "RGB")
if (np_frame1[1324][328].sum() > a):
    img.save('my98.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+335+470][j+435])
img = Image.fromarray(data, "RGB")
if (np_frame1[1306][306].sum() > a):
    img.save('my99.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+325+470][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1320][436].sum() > a):
    img.save('my100.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+320+470][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1310][384].sum() > a):
    img.save('my101.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+315+470][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1300][346].sum() > a):
    img.save('my102.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+310+470][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][314].sum() > a):
    img.save('my103.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1290][296].sum() > a):
    img.save('my104.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+305+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1288][284].sum() > a):
    img.save('my105.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+260+470][j+540])
img = Image.fromarray(data, "RGB")
if (np_frame1[1250][436].sum() > a):
    img.save('my106.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+265+470][j+510])
img = Image.fromarray(data, "RGB")
if (np_frame1[1260][386].sum() > a):
    img.save('my107.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275+470][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][346].sum() > a):
    img.save('my108.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+275+470][j+450])
img = Image.fromarray(data, "RGB")
if (np_frame1[1276][314].sum() > a):
    img.save('my109.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+280+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1280][296].sum() > a):
    img.save('my110.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+285+470][j+395])
img = Image.fromarray(data, "RGB")
if (np_frame1[1278][286].sum() > a):
    img.save('my111.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+210+470][j+500])
img = Image.fromarray(data, "RGB")
if (np_frame1[1186][394].sum() > a):
    img.save('my112.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+220+470][j+480])
img = Image.fromarray(data, "RGB")
if (np_frame1[1220][356].sum() > a):
    img.save('my113.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+235+470][j+460])
img = Image.fromarray(data, "RGB")
if (np_frame1[1242][328].sum() > a):
    img.save('my114.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+250+470][j+440])
img = Image.fromarray(data, "RGB") 
if (np_frame1[1260][306].sum() > a):
    img.save('my115.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+180+470][j+425])
img = Image.fromarray(data, "RGB")
if (np_frame1[1150][322].sum() > a):
    img.save('my116.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+197+470][j+415])
img = Image.fromarray(data, "RGB")
if (np_frame1[1194][310].sum() > a):
    img.save('my117.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+214+470][j+410])
img = Image.fromarray(data, "RGB")
if (np_frame1[1230][300].sum() > a):
    img.save('my118.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+236+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1254][290].sum() > a):
    img.save('my119.png')

for i in range(xlim):
    for j in range(ylim):
        data[i][j] = tuple(np_frame[i+255+470][j+400])
img = Image.fromarray(data, "RGB")
if (np_frame1[1270][286].sum() > a):
    img.save('my120.png')

# %%
#end
